# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/Colab Notebooks/customer_churn_prediction
# Out:
# /content/gdrive/My Drive/Colab Notebooks/customer_churn_prediction

# %%
dataset = pd.read_csv('customer.csv')

# %%
dataset.head(5)
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
dataset.shape
# Out:
# (7043, 21)

# %%
dataset.drop('customerID', axis = 1, inplace = True)

# %%
dataset.shape
# Out:
# (7043, 20)

# %%
dataset.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
dataset['TotalCharges'].values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(dataset['TotalCharges'], errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
dataset[pd.to_numeric(dataset['TotalCharges'], errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 488   Female              0     Yes  ...          52.55                  No
# 753     Male              0      No  ...          20.25                  No
# 936   Female              0     Yes  ...          80.85                  No
# 1082    Male              0     Yes  ...          25.75                  No
# 1340  Female              0     Yes  ...          56.05                  No
# 3331    Male              0     Yes  ...          19.85                  No
# 3826    Male              0     Yes  ...          25.35                  No
# 4380  Female              0     Yes  ...          20.00                  No
# 5218    Male              0     Yes  ...          19.70                  No
# 6670  Female              0     Yes  ...          73.35                  No
# 6754    Male              0      No  ...          61.90                  No
#
# [11 rows x 20 columns]

# %%
dataset[pd.to_numeric(dataset['TotalCharges'], errors='coerce').isnull()].shape
# Out:
# (11, 20)

# %%
dataset1 = dataset[dataset['TotalCharges'] != ' ']

# %%
dataset1['TotalCharges'] = pd.to_numeric(dataset1['TotalCharges'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
tenure_churn_no = dataset1[dataset1['Churn'] == 'No'].tenure
tenure_churn_yes = dataset1[dataset1['Churn'] == 'Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number of customers")
plt.title("Customer Churn Prediction Visualiztion")

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
mc_churn_no = dataset1[dataset1.Churn=='No'].MonthlyCharges      
mc_churn_yes = dataset1[dataset1.Churn=='Yes'].MonthlyCharges      

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
def print_unique_column_values(dataset):
  for column in dataset:
    if dataset[column].dtypes == 'object':
      print(f'{column}: {dataset[column].unique()}')

# %%
print_unique_column_values(dataset1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
dataset1.replace('No internet service', 'No', inplace = True)
dataset1.replace('No phone service', 'No', inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
print_unique_column_values(dataset1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
yes_no_columns = ['Partner', 'Dependents','PhoneService', 'MultipleLines','OnlineSecurity', 'OnlineBackup', 
                  'DeviceProtection', 'TechSupport', 'StreamingTV','StreamingMovies', 'PaperlessBilling', 'Churn']
for column in yes_no_columns:
  dataset1[column].replace({'Yes' : 1, 'No' : 0}, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
dataset1['gender'].replace({'Male' : 1, 'Female' : 0}, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
dataset2 = pd.get_dummies(data = dataset1, columns = ['InternetService','Contract','PaymentMethod'],drop_first= True)

# %%
dataset2.head(5)
# Out:
#    gender  ...  PaymentMethod_Mailed check
# 0       0  ...                           0
# 1       1  ...                           1
# 2       1  ...                           1
# 3       1  ...                           0
# 4       0  ...                           0
#
# [5 rows x 24 columns]

# %%
dataset2.shape
# Out:
# (7032, 24)

# %%
dataset2.dtypes
# Out:
# gender                                     int64
# SeniorCitizen                              int64
# Partner                                    int64
# Dependents                                 int64
# tenure                                     int64
# PhoneService                               int64
# MultipleLines                              int64
# OnlineSecurity                             int64
# OnlineBackup                               int64
# DeviceProtection                           int64
# TechSupport                                int64
# StreamingTV                                int64
# StreamingMovies                            int64
# PaperlessBilling                           int64
# MonthlyCharges                           float64
# TotalCharges                             float64
# Churn                                      int64
# InternetService_Fiber optic                uint8
# InternetService_No                         uint8
# Contract_One year                          uint8
# Contract_Two year                          uint8
# PaymentMethod_Credit card (automatic)      uint8
# PaymentMethod_Electronic check             uint8
# PaymentMethod_Mailed check                 uint8
# dtype: object

# %%
columns_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dataset2[columns_to_scale] = scaler.fit_transform(dataset2[columns_to_scale])

# %%
dataset2
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 0          0  ...                           0
# 1          1  ...                           1
# 2          1  ...                           1
# 3          1  ...                           0
# 4          0  ...                           0
# ...      ...  ...                         ...
# 7038       1  ...                           1
# 7039       0  ...                           0
# 7040       0  ...                           0
# 7041       1  ...                           1
# 7042       1  ...                           0
#
# [7032 rows x 24 columns]

# %%
features = dataset2.drop('Churn', axis = 1)
target = dataset2['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features,target,test_size=0.2,random_state=42)

# %%
from tensorflow import keras

model = keras.Sequential([
              keras.layers.Dense(23, input_shape = (23,), activation = 'relu'),
              keras.layers.Dense(1, activation = 'sigmoid')
])

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 1ms/step - loss: 0.4189 - accuracy: 0.8012
# Epoch 2/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3971 - accuracy: 0.8161
# Epoch 3/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4070 - accuracy: 0.8119
# Epoch 4/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4099 - accuracy: 0.8070
# Epoch 5/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4036 - accuracy: 0.8121
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4060 - accuracy: 0.8137
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8138
# Epoch 8/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4103 - accuracy: 0.8101
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.8095
# Epoch 10/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4118 - accuracy: 0.8023
# Epoch 11/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3901 - accuracy: 0.8207
# Epoch 12/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8128
# Epoch 13/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3912 - accuracy: 0.8141
# Epoch 14/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4024 - accuracy: 0.8181
# Epoch 15/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8177
# Epoch 16/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.8186
# Epoch 17/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8094
# Epoch 18/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.8133
# Epoch 19/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3932 - accuracy: 0.8114
# Epoch 20/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3974 - accuracy: 0.8085
# Epoch 21/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4006 - accuracy: 0.8155
# Epoch 22/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3905 - accuracy: 0.8163
# Epoch 23/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3956 - accuracy: 0.8128
# Epoch 24/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3946 - accuracy: 0.8179
# Epoch 25/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3893 - accuracy: 0.8169
# Epoch 26/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3949 - accuracy: 0.8172
# Epoch 27/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3996 - accuracy: 0.8096
# Epoch 28/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3845 - accuracy: 0.8205
# Epoch 29/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3901 - accuracy: 0.8185
# Epoch 30/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3923 - accuracy: 0.8261
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8230
# Epoch 32/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3891 - accuracy: 0.8237
# Epoch 33/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3920 - accuracy: 0.8153
# Epoch 34/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3895 - accuracy: 0.8191
# Epoch 35/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3871 - accuracy: 0.8252
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8225
# Epoch 37/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3850 - accuracy: 0.8208
# Epoch 38/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3977 - accuracy: 0.8080
# Epoch 39/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3810 - accuracy: 0.8186
# Epoch 40/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3822 - accuracy: 0.8244
# Epoch 41/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3776 - accuracy: 0.8271
# Epoch 42/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3899 - accuracy: 0.8218
# Epoch 43/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3897 - accuracy: 0.8192
# Epoch 44/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3796 - accuracy: 0.8281
# Epoch 45/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3814 - accuracy: 0.8249
# Epoch 46/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3578 - accuracy: 0.8397
# Epoch 47/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3752 - accuracy: 0.8287
# Epoch 48/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8199
# Epoch 49/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3888 - accuracy: 0.8165
# Epoch 50/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3800 - accuracy: 0.8283
# Epoch 51/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3867 - accuracy: 0.8210
# Epoch 52/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3846 - accuracy: 0.8241
# Epoch 53/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3946 - accuracy: 0.8162
# Epoch 54/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3842 - accuracy: 0.8205
# Epoch 55/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3884 - accuracy: 0.8158
# Epoch 56/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8298
# Epoch 57/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3816 - accuracy: 0.8220
# Epoch 58/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3792 - accuracy: 0.8254
# Epoch 59/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3908 - accuracy: 0.8155
# Epoch 60/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3860 - accuracy: 0.8205
# Epoch 61/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.8223
# Epoch 62/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8217
# Epoch 63/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3765 - accuracy: 0.8255
# Epoch 64/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3934 - accuracy: 0.8166
# Epoch 65/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.8198
# Epoch 66/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8256
# Epoch 67/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8193
# Epoch 68/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3813 - accuracy: 0.8186
# Epoch 69/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3822 - accuracy: 0.8179
# Epoch 70/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3878 - accuracy: 0.8141
# Epoch 71/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3864 - accuracy: 0.8180
# Epoch 72/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3969 - accuracy: 0.8131
# Epoch 73/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3935 - accuracy: 0.8141
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.8249
# Epoch 75/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8289
# Epoch 76/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3796 - accuracy: 0.8267
# Epoch 77/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.8185
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3842 - accuracy: 0.8247
# Epoch 79/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8192
# Epoch 80/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3879 - accuracy: 0.8143
# Epoch 81/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8295
# Epoch 82/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3859 - accuracy: 0.8217
# Epoch 83/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3730 - accuracy: 0.8245
# Epoch 84/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3674 - accuracy: 0.8316
# Epoch 85/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3825 - accuracy: 0.8252
# Epoch 86/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8127
# Epoch 87/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3810 - accuracy: 0.8264
# Epoch 88/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3910 - accuracy: 0.8191
# Epoch 89/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3779 - accuracy: 0.8202
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3767 - accuracy: 0.8246
# Epoch 91/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3742 - accuracy: 0.8209
# Epoch 92/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3717 - accuracy: 0.8304
# Epoch 93/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8213
# Epoch 94/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8189
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8193
# Epoch 96/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8226
# Epoch 97/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.8096
# Epoch 98/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3807 - accuracy: 0.8168
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3912 - accuracy: 0.8121
# Epoch 100/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3766 - accuracy: 0.8225

# %%
yp = model.predict(X_test)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1033
#            1       0.62      0.44      0.52       374
#
#     accuracy                           0.78      1407
#    macro avg       0.72      0.67      0.69      1407
# weighted avg       0.76      0.78      0.77      1407

# %%
import seaborn as sn
import tensorflow as tf
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
